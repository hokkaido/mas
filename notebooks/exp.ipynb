# %%
giga_path = '../datasets/sumdata/train'

# %%
import os
import random

def sample_giga(k=50):
    fa = os.path.join(giga_path, 'train.article.txt')
    ft = os.path.join(giga_path, 'train.title.txt')
    examples = []
    with open(fa) as articles:
        with open(ft) as titles:
            for n, article in enumerate(articles):
                title = titles.readline()
                example = (article.strip().split(), title.strip().split())
                if n < k:
                     examples.append(example)
                else:
                    r = random.randint(0, n)
                    if r < k:
                        examples[r] = example
    return examples

# %%
examples = sample_giga(25)

# %%
examples
# Out:
# [(['joe',
#    'jackson',
#    ',',
#    'the',
#    'patriarch',
#    'of',
#    'the',
#    'jackson',
#    'family',
#    ',',
#    'dished',
#    'out',
#    'thanksgiving',
#    'dinners',
#    'thursday',
#    'to',
#    'the',
#    'poor',
#    'and',
#    'said',
#    'he',
#    'was',
#    'not',
#    'concerned',
#    'about',
#    'the',
#    'child-molestation',
#    'allegations',
#    'against',
#    'his',
#    'famous',
#    'son',
#    '.'],
#   ['michael',
#    'jackson',
#    "'s",
#    'father',
#    'dishes',
#    'out',
#    'thanksgiving',
#    'dinners',
#    'for',
#    'poor']),
#  (['business',
#    'news',
#    'will',
#    'be',
#    'carried',
#    'inside',
#    'the',
#    'paper',
#    "'s",
#    'main',
#    'news',
#    'section',
#    'monday',
#    'through',
#    'saturday',
#    ',',
#    'effective',
#    'jan.',
#    '##',
#    ',',
#    'the',
#    'register',
#    'reported',
#    'on',
#    'its',
#    'web',
#    'site',
#    'monday',
#    ',',
#    'and',
#    'the',
#    'monday',
#    'business',
#    'tabloid',
#    'will',
#    'be',
#    'discontinued',
#    'after',
#    'next',
#    'week',
#    "'s",
#    'edition',
#    '.'],
#   ['orange', 'county', 'register', 'deletes', 'daily', 'business', 'section']),
#  (['priceline.com',
#    'and',
#    'alliance',
#    'capital',
#    'partners',
#    'today',
#    'announced',
#    'a',
#    'joint',
#    'venture',
#    'that',
#    'will',
#    'allow',
#    'consumers',
#    'to',
#    'set',
#    'the',
#    'prices',
#    'and',
#    'terms',
#    'they',
#    'want',
#    'to',
#    'pay',
#    'for',
#    'home',
#    'mortgages',
#    '.'],
#   ['priceline.com', 'to', 'offer', 'mortgages']),
#  (['the',
#    'chairman',
#    'of',
#    'the',
#    'standing',
#    'committee',
#    'of',
#    'china',
#    "'s",
#    'national',
#    'people',
#    "'s",
#    'congress',
#    'says',
#    'that',
#    'the',
#    'npc',
#    'wants',
#    'to',
#    'find',
#    'various',
#    'ways',
#    'to',
#    'co-operate',
#    'with',
#    'the',
#    'parliament',
#    'of',
#    'tadzhikistan',
#    'to',
#    'develop',
#    'good-neighborly',
#    'relations',
#    '.'],
#   ['npc', 'chairman', 'meets', 'with', 'tadzhikistan', 'president']),
#  (['the',
#    'world',
#    "'s",
#    'biggest',
#    'logistics',
#    'company',
#    'deutsche',
#    'post',
#    'on',
#    'wednesday',
#    'reported',
#    'a',
#    'net',
#    'loss',
#    'of',
#    '#.##',
#    'billion',
#    'euros',
#    '-lrb-',
#    '#.##',
#    'billion',
#    'dollars',
#    '-rrb-',
#    'for',
#    '####',
#    '.'],
#   ['deutsche',
#    'post',
#    'reports',
#    '#.##',
#    'bln',
#    'euro',
#    'loss',
#    'in',
#    '####']),
#  (['israeli',
#    'pacifists',
#    'demonstrated',
#    'saturday',
#    'in',
#    'front',
#    'of',
#    'prime',
#    'minister',
#    'ehud',
#    'olmert',
#    "'s",
#    'jerusalem',
#    'home',
#    'to',
#    'support',
#    'him',
#    'as',
#    'he',
#    'heads',
#    'for',
#    'a',
#    'meeting',
#    'in',
#    'the',
#    'united',
#    'states',
#    'aimed',
#    'at',
#    'reviving',
#    'peace',
#    'talks',
#    'with',
#    'the',
#    'palestinians',
#    ',',
#    'organisers',
#    'said',
#    '.'],
#   ['israeli', 'peace', 'demo', 'wishes', 'olmert', 'well']),
#  (['the',
#    'body',
#    'of',
#    'a',
#    'veteran',
#    'crime',
#    'reporter',
#    'was',
#    'found',
#    'in',
#    'an',
#    'irrigation',
#    'ditch',
#    'early',
#    'tuesday',
#    'in',
#    'the',
#    'drug-plagued',
#    'northern',
#    'mexican',
#    'state',
#    'of',
#    'durango',
#    ',',
#    'hours',
#    'after',
#    'he',
#    'was',
#    'kidnapped',
#    'by',
#    'gunmen',
#    'from',
#    'his',
#    'home',
#    '.'],
#   ['mexican', 'journalist', 'killed', 'in', 'northern', 'state']),
#  (['u.n.',
#    'and',
#    'uzbek',
#    'officials',
#    'inspected',
#    'barges',
#    'and',
#    'food',
#    'storage',
#    'warehouses',
#    'sunday',
#    'and',
#    'said',
#    'that',
#    'u.n.',
#    'aid',
#    'shipments',
#    'across',
#    'the',
#    'river',
#    'border',
#    'with',
#    'afghanistan',
#    'could',
#    'begin',
#    'by',
#    'wednesday',
#    '.'],
#   ['first',
#    'shipment',
#    'of',
#    'humanitarian',
#    'aid',
#    'for',
#    'afghanistan',
#    'expected',
#    'to']),
#  (['the',
#    'united',
#    'states',
#    'is',
#    'suspending',
#    'millions',
#    'of',
#    'u.s.',
#    'dollars',
#    'in',
#    'aid',
#    'to',
#    'niger',
#    'and',
#    'imposing',
#    'travel',
#    'restrictions',
#    'on',
#    'the',
#    'west',
#    'african',
#    'country',
#    "'s",
#    'leadership',
#    ',',
#    'as',
#    'nigerian',
#    'president',
#    'mamadou',
#    'tandja',
#    'refused',
#    'to',
#    'step',
#    'down',
#    ',',
#    'the',
#    'state',
#    'department',
#    'announced',
#    'wednesday',
#    '.'],
#   ['u.s.',
#    'suspends',
#    'aid',
#    'imposes',
#    'travel',
#    'restrictions',
#    'on',
#    'niger']),
#  (['the',
#    'indonesian',
#    'government',
#    'should',
#    'not',
#    'issue',
#    'price',
#    'hike',
#    'policies',
#    ',',
#    'which',
#    'prompted',
#    'massive',
#    'reaction',
#    'across',
#    'the',
#    'country',
#    ',',
#    'said',
#    'chairman',
#    'of',
#    'commission',
#    'eight',
#    'of',
#    'the',
#    'indonesian',
#    'house',
#    'of',
#    'representatives',
#    '-lrb-',
#    'dpr',
#    '-rrb-',
#    '<unk>',
#    'prayitno',
#    'here',
#    'on',
#    'friday',
#    '.'],
#   ['indonesian', 'government', 'criticized', 'over', 'price', 'policies']),
#  (['with',
#    'little',
#    'fanfare',
#    'over',
#    'the',
#    'past',
#    'three',
#    'years',
#    ',',
#    '<unk>',
#    'giant',
#    'electronic',
#    'data',
#    'systems',
#    'corp.',
#    'has',
#    'become',
#    'a',
#    'significant',
#    'player',
#    'in',
#    'hollywood',
#    "'s",
#    'booming',
#    'post-production',
#    'business',
#    '.'],
#   ['digital', 'specialists', 'have', 'grown', 'with', 'hollywood']),
#  (['after',
#    'four',
#    'pain-killing',
#    'injections',
#    'to',
#    'numb',
#    'his',
#    'injured',
#    'right',
#    'foot',
#    ',',
#    'alexei',
#    'yagudin',
#    'skated',
#    'tuesday',
#    'in',
#    'the',
#    'men',
#    "'s",
#    'short',
#    'program',
#    'at',
#    'the',
#    'world',
#    'figure',
#    'skating',
#    'championships',
#    '.'],
#   ['yagudin', 'skates', 'despite', 'foot', 'pain']),
#  (['spain',
#    "'s",
#    'first',
#    'woman',
#    'defense',
#    'minister',
#    'was',
#    'among',
#    '##',
#    'cabinet',
#    'members',
#    'sworn',
#    'into',
#    'office',
#    'monday',
#    '.'],
#   ['spain',
#    's',
#    '#st',
#    'woman',
#    'defense',
#    'minister',
#    'takes',
#    'oath',
#    'as',
#    'new',
#    'cabinet',
#    'takes',
#    'office']),
#  (['asian',
#    'stocks',
#    'closed',
#    'mixed',
#    'thursday',
#    'but',
#    'china',
#    'shone',
#    'as',
#    'the',
#    'shanghai',
#    'market',
#    'rocketed',
#    'nearly',
#    '##',
#    'percent',
#    'after',
#    'the',
#    'government',
#    'slashed',
#    'stamp',
#    'duty',
#    'to',
#    'shore',
#    'up',
#    'share',
#    'prices',
#    '.'],
#   ['asian',
#    'stocks',
#    'close',
#    'mixed',
#    'but',
#    'china',
#    'surges',
#    'nearly',
#    '##',
#    'pct']),
#  (['top',
#    'favorite',
#    'dream',
#    'team',
#    'of',
#    'the',
#    'united',
#    'states',
#    'scored',
#    'a',
#    'hard',
#    'earned',
#    'victory',
#    'of',
#    '##-##',
#    'over',
#    'south',
#    'american',
#    'squad',
#    'argentina',
#    'in',
#    'their',
#    'opening',
#    'match',
#    'of',
#    'the',
#    'basketball',
#    'competition',
#    'at',
#    'the',
#    'centennial',
#    'olympic',
#    'games',
#    'here',
#    'saturday',
#    '.'],
#   ['dream', 'team', 'wins', 'opener', 'in', 'olympic', 'basketball']),
#  (['juan',
#    'uribe',
#    'homered',
#    'and',
#    'had',
#    'five',
#    'rbis',
#    'as',
#    'the',
#    'chicago',
#    'white',
#    'sox',
#    'beat',
#    'the',
#    'chicago',
#    'cubs',
#    '#-#',
#    'on',
#    'friday',
#    'after',
#    'the',
#    'two',
#    'central',
#    'combatants',
#    'in',
#    'a',
#    'brawl',
#    'earlier',
#    'this',
#    'season',
#    'chatted',
#    'and',
#    'shook',
#    'hands',
#    '.'],
#   ['white', 'sox', 'beat', 'cubs', 'in', 'chicago', 'derby']),
#  (['a',
#    'romanian',
#    'service',
#    'man',
#    'was',
#    'killed',
#    'in',
#    'afghanistan',
#    'thursday',
#    'afternoon',
#    ',',
#    'announced',
#    'the',
#    'press',
#    'office',
#    'of',
#    'the',
#    'romanian',
#    'defense',
#    'ministry',
#    '.'],
#   ['one', 'romanian', 'service', 'man', 'killed', 'in', 'afghanistan']),
#  (['dutch',
#    'airline',
#    'klm',
#    'suffered',
#    'a',
#    'net',
#    'loss',
#    'of',
#    '##',
#    'million',
#    'euros',
#    '-lrb-',
#    '##',
#    'million',
#    'us',
#    'dollars',
#    '-rrb-',
#    'in',
#    'the',
#    'first',
#    'quarter',
#    'of',
#    'the',
#    'fiscal',
#    'year',
#    '####\\/####',
#    ',',
#    'said',
#    'its',
#    'latest',
#    'financial',
#    'report',
#    '.'],
#   ['dutch', 'airline', 'reports', 'first-quarter', 'net', 'loss']),
#  (['british',
#    'treasury',
#    'chief',
#    'gordon',
#    'brown',
#    'toured',
#    'a',
#    'school',
#    'in',
#    'africa',
#    "'s",
#    'largest',
#    'slum',
#    'to',
#    'study',
#    'the',
#    'impact',
#    'of',
#    'free',
#    'primary',
#    'education',
#    'on',
#    'efforts',
#    'to',
#    'cut',
#    'poverty',
#    ',',
#    'preparing',
#    'a',
#    'case',
#    'to',
#    'encourage',
#    'rich',
#    'nations',
#    'to',
#    'boost',
#    'debt',
#    'relief',
#    'and',
#    'aid',
#    'to',
#    'the',
#    'poor',
#    '.'],
#   ['british',
#    'treasury',
#    'chief',
#    'begins',
#    'africa',
#    'tour',
#    'visits',
#    'largest',
#    'african',
#    'slum']),
#  (['us',
#    'automaker',
#    'chrysler',
#    'group',
#    'said',
#    'monday',
#    'that',
#    'improved',
#    'demand',
#    'would',
#    'allow',
#    'it',
#    'to',
#    'keep',
#    'open',
#    'a',
#    'detroit',
#    'plant',
#    'slated',
#    'for',
#    'closure',
#    'and',
#    'maintain',
#    'a',
#    'third',
#    'shift',
#    'at',
#    'a',
#    'canadian',
#    'facility',
#    '.'],
#   ['improved', 'demand', 'keeps', 'chrysler', 'detroit', 'plant', 'open']),
#  (['world',
#    'boxing',
#    'association',
#    'bantamweight',
#    'champion',
#    'paulie',
#    'ayala',
#    'is',
#    'close',
#    'to',
#    'finalizing',
#    'an',
#    'agreement',
#    'to',
#    'fight',
#    'johnny',
#    'bredahl',
#    'of',
#    'denmark',
#    'on',
#    'march',
#    '#',
#    'in',
#    'las',
#    'vegas',
#    'for',
#    'his',
#    'second',
#    'title',
#    'defense',
#    '.'],
#   ['<unk>',
#    'ayala',
#    'to',
#    'defend',
#    'wba',
#    'title',
#    'march',
#    '#',
#    'in',
#    'las',
#    'vegas']),
#  (['jaromir',
#    'jagr',
#    'went',
#    'on',
#    'another',
#    'offensive',
#    'onslaught',
#    'against',
#    'the',
#    'rangers',
#    'with',
#    'a',
#    'goal',
#    'and',
#    'an',
#    'assist',
#    'during',
#    'pittsburgh',
#    "'s",
#    'three-goal',
#    'first',
#    'period',
#    'as',
#    'the',
#    'penguins',
#    'beat',
#    'new',
#    'york',
#    '#-#',
#    'friday',
#    'night',
#    '.'],
#   ['penguins', '#', 'rangers', '#']),
#  (['how',
#    'well',
#    'john',
#    'starks',
#    'adjusts',
#    'to',
#    'his',
#    '<unk>',
#    'role',
#    'this',
#    'season',
#    'will',
#    'be',
#    'critical',
#    'for',
#    'the',
#    'knicks',
#    '.'],
#   ['starks', 'now', 'embracing', 'his', 'role', 'off', 'the', 'bench']),
#  (['defense',
#    'secretary',
#    'robert',
#    'gates',
#    'is',
#    'defending',
#    'his',
#    'plans',
#    'to',
#    'trim',
#    'more',
#    'than',
#    'a',
#    'billion',
#    'dollars',
#    'from',
#    'the',
#    'planned',
#    'system',
#    'to',
#    'build',
#    'a',
#    'broad',
#    'missile',
#    'shield',
#    'for',
#    'the',
#    'u.s.',
#    'and',
#    'its',
#    'allies',
#    '.'],
#   ['gates', 'backs', 'us', 'missile', 'defense', 'despite', 'budget', 'cuts']),
#  (['amnesty',
#    'international',
#    'called',
#    'on',
#    'spanish',
#    'authorities',
#    'to',
#    'respect',
#    '``',
#    'the',
#    'right',
#    'to',
#    'peaceful',
#    'protest',
#    "''",
#    'and',
#    'allow',
#    'a',
#    'march',
#    'in',
#    'favor',
#    'of',
#    'a',
#    'basque',
#    'political',
#    'party',
#    'accused',
#    'of',
#    'supporting',
#    'separatist',
#    'terrorism',
#    '.'],
#   ['amnesty',
#    'demands',
#    'spain',
#    'allow',
#    'protest',
#    'in',
#    'favor',
#    'of',
#    'banned',
#    'separatist',
#    'party'])]

# %%
from collections import Counter

def shared_tokens(a, b):
    ac = Counter(a)
    bc = Counter(b)
    return (ac & bc).keys()

# %%
for ex in examples:
    print(shared_tokens(*ex))
# Out:
# dict_keys(['jackson', 'out', 'thanksgiving', 'dinners', 'poor'])
# dict_keys(['business', 'section', 'register'])
# dict_keys(['priceline.com', 'to', 'mortgages'])
# dict_keys(['chairman', 'npc', 'with', 'tadzhikistan'])
# dict_keys(['deutsche', 'post', 'loss', '#.##', '####'])
# dict_keys(['israeli', 'olmert', 'peace'])
# dict_keys(['in', 'northern', 'mexican', 'state'])
# dict_keys(['aid', 'afghanistan'])
# dict_keys(['u.s.', 'aid', 'niger', 'travel', 'restrictions', 'on'])
# dict_keys(['indonesian', 'government', 'price', 'policies'])
# dict_keys(['with', 'hollywood'])
# dict_keys(['foot', 'yagudin'])
# dict_keys(['spain', 'woman', 'defense', 'minister', 'cabinet', 'office'])
# dict_keys(['asian', 'stocks', 'mixed', 'but', 'china', 'nearly', '##'])
# dict_keys(['dream', 'team', 'in', 'basketball', 'olympic'])
# dict_keys(['chicago', 'white', 'sox', 'beat', 'cubs', 'in'])
# dict_keys(['romanian', 'service', 'man', 'killed', 'in', 'afghanistan'])
# dict_keys(['dutch', 'airline', 'net', 'loss'])
# dict_keys(['british', 'treasury', 'chief', 'africa', 'largest', 'slum'])
# dict_keys(['chrysler', 'improved', 'demand', 'open', 'detroit', 'plant'])
# dict_keys(['ayala', 'to', 'march', '#', 'in', 'las', 'vegas', 'title'])
# dict_keys(['rangers', 'penguins'])
# dict_keys(['starks', 'his', 'role', 'the'])
# dict_keys(['defense', 'gates', 'missile'])
# dict_keys(['amnesty', 'protest', 'allow', 'in', 'favor', 'of', 'party', 'separatist'])

# %%
from pytorch_
